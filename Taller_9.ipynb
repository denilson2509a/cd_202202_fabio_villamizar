# %% [markdown]
# <a href="https://colab.research.google.com/github/denilson2509a/cd_202202_fabio_villamizar/blob/main/Taller_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm

# %%
df= pd.read_csv("https://raw.githubusercontent.com/adiacla/bigdata/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.drop("Cabin",axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df=df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 885      5            382652  29.1250        Q
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [712 rows x 11 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
x=df.iloc[:,[5,6,7]]
y=df.Survived
logit_model=sm.Logit(y,x)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.665234
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      709
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 13 Nov 2022   Pseudo R-squ.:                 0.01416
# Time:                        16:56:05   Log-Likelihood:                -473.65
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                  0.001108
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0135      0.003     -5.273      0.000      -0.019      -0.008
# SibSp         -0.1952      0.087     -2.240      0.025      -0.366      -0.024
# Parch          0.2616      0.097      2.703      0.007       0.072       0.451
# ==============================================================================

# %%
# 1 para hombres, 0 para mujeres
df = pd.get_dummies(df, columns = ["Sex"], drop_first = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  39.0      0      5
# 886                              Montvila, Rev. Juozas  27.0      0      0
# 887                       Graham, Miss. Margaret Edith  19.0      0      0
# 889                              Behr, Mr. Karl Howell  26.0      0      0
# 890                                Dooley, Mr. Patrick  32.0      0      0
#
#                Ticket     Fare Embarked  Sex_male
# 0           A/5 21171   7.2500        S         1
# 1            PC 17599  71.2833        C         0
# 2    STON/O2. 3101282   7.9250        S         0
# 3              113803  53.1000        S         0
# 4              373450   8.0500        S         1
# ..                ...      ...      ...       ...
# 885            382652  29.1250        Q         0
# 886            211536  13.0000        S         1
# 887            112053  30.0000        S         0
# 889            111369  30.0000        C         1
# 890            370376   7.7500        Q         1
#
# [712 rows x 11 columns]

# %%
x = df.iloc[:,[4,5,6,10]]
y = df.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.548462
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      708
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 13 Nov 2022   Pseudo R-squ.:                  0.1872
# Time:                        16:56:05   Log-Likelihood:                -390.51
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                 9.300e-39
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0208      0.004      5.198      0.000       0.013       0.029
# SibSp         -0.0170      0.102     -0.167      0.867      -0.216       0.182
# Parch          0.1304      0.110      1.188      0.235      -0.085       0.346
# Sex_male      -2.0482      0.175    -11.722      0.000      -2.391      -1.706
# ==============================================================================

# %%
hashEmbarked={
    1:'S', 
    2:'C',
    3:'Q'
}

df['EmbarkedNum'] = df['Embarked'].replace(
  # Reemplaza cada valor por el valor en la segunda lista en el mismo índice del match.
  hashEmbarked.values(), # Lista de Strings
  hashEmbarked.keys() # Lista de Números
)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  39.0      0      5
# 886                              Montvila, Rev. Juozas  27.0      0      0
# 887                       Graham, Miss. Margaret Edith  19.0      0      0
# 889                              Behr, Mr. Karl Howell  26.0      0      0
# 890                                Dooley, Mr. Patrick  32.0      0      0
#
#                Ticket     Fare Embarked  Sex_male  EmbarkedNum
# 0           A/5 21171   7.2500        S         1            1
# 1            PC 17599  71.2833        C         0            2
# 2    STON/O2. 3101282   7.9250        S         0            1
# 3              113803  53.1000        S         0            1
# 4              373450   8.0500        S         1            1
# ..                ...      ...      ...       ...          ...
# 885            382652  29.1250        Q         0            3
# 886            211536  13.0000        S         1            1
# 887            112053  30.0000        S         0            1
# 889            111369  30.0000        C         1            2
# 890            370376   7.7500        Q         1            3
#
# [712 rows x 12 columns]

# %%
x = df.iloc[:,[4,5,6,10,11]]
y = df.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.527540
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      707
# Method:                           MLE   Df Model:                            4
# Date:                Sun, 13 Nov 2022   Pseudo R-squ.:                  0.2182
# Time:                        16:56:05   Log-Likelihood:                -375.61
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                 3.103e-44
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Age             0.0027      0.005      0.517      0.605      -0.008       0.013
# SibSp          -0.1628      0.107     -1.522      0.128      -0.372       0.047
# Parch           0.0450      0.112      0.403      0.687      -0.174       0.264
# Sex_male       -2.2809      0.183    -12.481      0.000      -2.639      -1.923
# EmbarkedNum     0.7064      0.135      5.223      0.000       0.441       0.971
# ===============================================================================

# %% [markdown]
# Taller-9

# %%
from sklearn.model_selection import train_test_split 

train, test = train_test_split(df, test_size = 0.20)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 379          380         0       3
# 585          586         1       1
# 690          691         1       1
# 488          489         0       3
# 360          361         0       3
# ..           ...       ...     ...
# 710          711         1       1
# 751          752         1       3
# 37            38         0       3
# 571          572         1       1
# 189          190         0       3
#
#                                                  Name   Age  SibSp  Parch  \
# 379                       Gustafsson, Mr. Karl Gideon  19.0      0      0
# 585                               Taussig, Miss. Ruth  18.0      0      2
# 690                           Dick, Mr. Albert Adrian  31.0      1      0
# 488                     Somerton, Mr. Francis William  30.0      0      0
# 360                                Skoog, Mr. Wilhelm  40.0      1      4
# ..                                                ...   ...    ...    ...
# 710  Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")  24.0      0      0
# 751                               Moor, Master. Meier   6.0      0      1
# 37                           Cann, Mr. Ernest Charles  21.0      0      0
# 571     Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0      2      0
# 189                               Turcin, Mr. Stjepan  36.0      0      0
#
#          Ticket     Fare Embarked  Sex_male  EmbarkedNum
# 379      347069   7.7750        S         1            1
# 585      110413  79.6500        S         0            1
# 690       17474  57.0000        S         1            1
# 488  A.5. 18509   8.0500        S         1            1
# 360      347088  27.9000        S         1            1
# ..          ...      ...      ...       ...          ...
# 710    PC 17482  49.5042        C         0            2
# 751      392096  12.4750        S         1            1
# 37   A./5. 2152   8.0500        S         1            1
# 571       11769  51.4792        S         0            1
# 189      349247   7.8958        S         1            1
#
# [569 rows x 12 columns]

# %%
x = train.iloc[:,[4,5,6]]
y = train.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()

resum = result.summary()

print(resum)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.658362
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  569
# Model:                          Logit   Df Residuals:                      566
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 13 Nov 2022   Pseudo R-squ.:                 0.01563
# Time:                        16:56:06   Log-Likelihood:                -374.61
# converged:                       True   LL-Null:                       -380.56
# Covariance Type:            nonrobust   LLR p-value:                  0.002607
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0151      0.003     -5.164      0.000      -0.021      -0.009
# SibSp         -0.2360      0.098     -2.413      0.016      -0.428      -0.044
# Parch          0.2649      0.106      2.502      0.012       0.057       0.472
# ==============================================================================

# %%
#edadcoefEdad + sibcoefSibSp + parch*coefParch
import statsmodels.api as sm

results_summary = resum

resultsHTML = results_summary.tables[1].as_html()

table = pd.read_html(resultsHTML, header=0, index_col=0)[0]

# %%
ageCoef = table['coef'].values[0]
SibSpCoef = table['coef'].values[1]
ParchCoef = table['coef'].values[2]

# %%
import math

# %%
truePositive = 0
falseNegative = 0
falsePositive = 0
trueNegative = 0

probList = []

for i in test.index:

  valor = (ageCoef*test['Age'][i]) + (SibSpCoef*test['SibSp'][i]) + (ParchCoef*test['Parch'][i])

  prob = 1 / (1 + math.e ** (-1 * valor))

  probList.append(prob)

  if prob<0.5:
    trunc = 0
  else:
    trunc = 1

  trueVal = test['Survived'][i]

  if(trueVal == 1 and trunc == 1):
    truePositive += 1
  elif(trueVal == 1 and trunc == 0):
    falseNegative += 1
  elif(trueVal == 0 and trunc == 1):
    falsePositive += 1
  elif(trueVal == 0 and trunc == 0):
    trueNegative += 1

print("Verdadero Positivo: "+ str(truePositive))
print("Falso Negativo: " + str(falseNegative))
print("Falso Positivo: " + str(falsePositive))
print("Verdadero Negativo: " + str(trueNegative))

print(probList)
# Out:
# Verdadero Positivo: 5
# Falso Negativo: 61
# Falso Positivo: 1
# Verdadero Negativo: 76
# [0.3743968250032003, 0.2589563530254598, 0.391931609739971, 0.34998617003853194, 0.49590009189219514, 0.33637290654975144, 0.2589563530254598, 0.4140373168101839, 0.31645747465253143, 0.3478280512893274, 0.43352094403237207, 0.3814967770838001, 0.49590009189219514, 0.37056353606521925, 0.3886477263763144, 0.40309156063164264, 0.31973280330135156, 0.3814967770838001, 0.35185392309770364, 0.4324652511383205, 0.5417525437148012, 0.31116038025935167, 0.3792577232382414, 0.375709398325532, 0.2816685635560637, 0.389979116874249, 0.3850660466020702, 0.33762411635415557, 0.3708668071154858, 0.34655881149640794, 0.6223653251134583, 0.3708668071154858, 0.4140373168101839, 0.37217436711860136, 0.3263368672415173, 0.4213826621973928, 0.3067409837181513, 0.29521268786628047, 0.38685535668571025, 0.4177054257508645, 0.37987001049537517, 0.4067300078928128, 0.42981646701901244, 0.45857020750075556, 0.3715670517202537, 0.4067300078928128, 0.34285434143809185, 0.3194501147293502, 0.47768982405279037, 0.33425556513515803, 0.3065496311562515, 0.35342909090255187, 0.3708668071154858, 0.4398920936368172, 0.6259076162386616, 0.3478280512893274, 0.28896830418859976, 0.4103787180229774, 0.2767180501415145, 0.26345262457233926, 0.4140373168101839, 0.3027155179106414, 0.3886477263763144, 0.41220680489204914, 0.327569172706243, 0.3288038603244294, 0.44702457262262696, 0.33425556513515803, 0.42506863950941504, 0.35342909090255187, 0.35470983380979354, 0.4398920936368172, 0.28896830418859976, 0.4324652511383205, 0.343147298059347, 0.34655881149640794, 0.4103787180229774, 0.3603604578454531, 0.5509475702884604, 0.33637290654975144, 0.47327549254315177, 0.3130066878647206, 0.25500392741507677, 0.2847338147447448, 0.4067300078928128, 0.39584692924797543, 0.3230260113951943, 0.3603604578454531, 0.367350528619039, 0.42876296720883306, 0.31767006582286245, 0.3293779144108153, 0.3600608612360927, 0.43617509362323825, 0.2725942522852814, 0.334689636415672, 0.4398920936368172, 0.3132862993480442, 0.49967500004577076, 0.37217436711860136, 0.37794025819952015, 0.46436054227016776, 0.564144584103043, 0.40309156063164264, 0.43617509362323825, 0.34655881149640794, 0.3613522052446405, 0.3444106289236633, 0.4103787180229774, 0.5618072653942671, 0.4324652511383205, 0.2767180501415145, 0.3886477263763144, 0.3067409837181513, 0.4177054257508645, 0.35688728516741086, 0.4378727265427432, 0.3296651326129466, 0.39946374601613166, 0.42876296720883306, 0.33762411635415557, 0.4456098221749266, 0.4324652511383205, 0.42506863950941504, 0.3648441791411712, 0.4398920936368172, 0.43617509362323825, 0.3708668071154858, 0.3309038327257334, 0.4140373168101839, 0.22670692717774646, 0.42322458256199186, 0.4213826621973928, 0.27370607035419503, 0.40855310338523015, 0.34998617003853194, 0.367350528619039, 0.3708668071154858, 0.37263011875960983, 0.4324652511383205, 0.3309038327257334, 0.40309156063164264, 0.367350528619039]

# %%
p = truePositive / (truePositive + falsePositive)
print("Precision: " + str(p*100))
# Out:
# Precision: 83.33333333333334

# %%
r = truePositive / (falseNegative + truePositive)
print("Exhaustividad: " + str(r*100))
# Out:
# Exhaustividad: 7.575757575757576

# %% [markdown]
# Ahora con Sexo

# %%
x = train.iloc[:,[4,5,6,10]]
y = train.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.550552
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  569
# Model:                          Logit   Df Residuals:                      565
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 13 Nov 2022   Pseudo R-squ.:                  0.1768
# Time:                        16:56:06   Log-Likelihood:                -313.26
# converged:                       True   LL-Null:                       -380.56
# Covariance Type:            nonrobust   LLR p-value:                 5.549e-29
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0181      0.004      4.059      0.000       0.009       0.027
# SibSp         -0.0892      0.112     -0.793      0.428      -0.310       0.131
# Parch          0.1556      0.119      1.305      0.192      -0.078       0.389
# Sex_male      -1.9681      0.194    -10.155      0.000      -2.348      -1.588
# ==============================================================================

# %%
import statsmodels.api as sm

results_summary = result.summary()

resultsHTML = results_summary.tables[1].as_html()

table = pd.read_html(resultsHTML, header=0, index_col=0)[0]

# %%
ageCoef = table['coef'].values[0]
SibSpCoef = table['coef'].values[1]
ParchCoef = table['coef'].values[2]
SexMaleCoef = table['coef'].values[3]

# %%
truePositive = 0
falseNegative = 0
falsePositive = 0
trueNegative = 0

probList = []

for i in test.index:

  valor = (ageCoef*test['Age'][i]) + (SibSpCoef*test['SibSp'][i]) + (ParchCoef*test['Parch'][i]) + (SexMaleCoef*test['Parch'][i])

  prob = 1 / (1 + math.e ** (-1 * valor))

  probList.append(prob)

  if prob<0.5:
    trunc = 0
  else:
    trunc = 1

  trueVal = test['Survived'][i]

  if(trueVal == 1 and trunc == 1):
    truePositive += 1
  elif(trueVal == 1 and trunc == 0):
    falseNegative += 1
  elif(trueVal == 0 and trunc == 1):
    falsePositive += 1
  elif(trueVal == 0 and trunc == 0):
    trueNegative += 1

print("Verdadero Positivo: "+ str(truePositive))
print("Falso Negativo: " + str(falseNegative))
print("Falso Positivo: " + str(falsePositive))
print("Verdadero Negativo: " + str(trueNegative))

print(probList)
# Out:
# Verdadero Positivo: 45
# Falso Negativo: 21
# Falso Positivo: 65
# Verdadero Negativo: 12
# [0.6491716288095085, 0.7085185761328839, 0.20741140609501363, 0.6774548976285714, 0.1361784558963264, 0.6930675971432794, 0.7085185761328839, 0.6025975342423846, 0.7156733307691882, 0.5942107214851406, 0.12802892919020217, 0.6408833055786468, 0.1361784558963264, 0.2258315706640255, 0.6325100178154341, 0.6155257585093361, 0.7119759194127935, 0.6408833055786468, 0.31806035423894014, 0.5807371026084075, 0.039520997804204754, 0.6411824482115257, 0.5544087058776257, 0.5588756033767538, 0.7543965657985732, 0.5409580167172245, 0.6367070208336125, 0.607233951213563, 0.6532826524207207, 0.6813971543786318, 0.0002147545569316597, 0.6532826524207207, 0.6025975342423846, 0.563332990985174, 0.7044959416252288, 0.5938972214917688, 0.7265920149936651, 0.6617270397564465, 0.634611075765063, 0.5982551140503789, 0.2875116868679298, 0.6112334666758695, 0.13006320895721266, 0.5496112224204875, 0.029994142428444927, 0.6112334666758695, 0.2521459032518995, 0.27677809771458617, 0.05300537971074094, 0.6115423372192652, 0.02039419398942862, 0.6734872354373036, 0.6532826524207207, 0.5718982034898707, 0.02641893770416575, 0.5942107214851406, 0.6697821672322685, 0.6069238568851832, 0.6855938983778822, 0.34644559228417665, 0.6025975342423846, 0.5636527502253681, 0.6325100178154341, 0.6047627464492117, 0.6201064323430902, 0.5277713887758501, 0.16629726029803718, 0.6115423372192652, 0.5895244912981846, 0.6734872354373036, 0.5854531095121036, 0.5718982034898707, 0.6697821672322685, 0.5807371026084075, 0.6853136094151082, 0.6813971543786318, 0.6069238568851832, 0.6654773472361732, 0.1493002331180652, 0.6930675971432794, 0.14946542098111149, 0.019683398838119384, 0.7833166586370123, 0.7510275335941146, 0.6112334666758695, 0.6240560206914695, 0.7082500273696474, 0.6654773472361732, 0.657370928384956, 0.585137567407375, 0.6328121391522826, 0.26604153433831335, 0.23546599433502927, 0.5763237581753548, 0.7643179109818153, 0.6949893865291374, 0.5718982034898707, 0.11480224831089492, 0.13406326920497239, 0.563332990985174, 0.6450383461255521, 0.0020645011920959436, 0.035598644175663385, 0.6155257585093361, 0.010463951869028031, 0.6813971543786318, 0.17414944803501342, 0.5985675238140991, 0.6069238568851832, 0.025089408030284, 0.5807371026084075, 0.6855938983778822, 0.6325100178154341, 0.7265920149936651, 0.5982551140503789, 0.6694945775765003, 0.044676602017985144, 0.7007139628297921, 0.6198001377835131, 0.585137567407375, 0.607233951213563, 0.12160428341459542, 0.5807371026084075, 0.5895244912981846, 0.17156161379735319, 0.5718982034898707, 0.5763237581753548, 0.6532826524207207, 0.6158333622078765, 0.6025975342423846, 0.6740587230020565, 0.5917126710649069, 0.5938972214917688, 0.6894822739769616, 0.609080788948761, 0.6774548976285714, 0.657370928384956, 0.6532826524207207, 0.6512299538332608, 0.5807371026084075, 0.6158333622078765, 0.6155257585093361, 0.657370928384956]

# %%
p = truePositive / (truePositive + falsePositive)
print("Precision: " + str(p*100))
# Out:
# Precision: 40.909090909090914

# %%
r = truePositive / (falseNegative + truePositive)
print("Exhaustividad: " + str(r*100))
# Out:
# Exhaustividad: 68.18181818181817
